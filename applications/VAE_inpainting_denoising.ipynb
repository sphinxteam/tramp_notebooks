# %% [markdown]
# # <center> Demonstration <font color=#00a0a0>TR</font><font color=#e5ad00>AMP</font> </center>

# %% [markdown]
# This notebook illustrates the <a href="https://github.com/sphinxteam/tramp"> TRAMP package</a> on simple models: denoising and inpainting of MNIST or Fashion-MNIST samples, using a VAE prior trained on the same data-set. <br/>
# For demonstration we use a simple <b> VAE prior </b>: ([Dense(20, 400) + bias -> relu  -> Dense(400, 784) + bias -> sigmoid ]). <a href='https://keras.io/examples/variational_autoencoder/'> See details </a>

# %% [markdown]
# #### Requirements:
# * numpy / pandas / scipy / matplotlib
# * networkx==1.11
# * daft
# * <a href="https://github.com/sphinxteam/tramp"> tramp</a>

# %%
from VAE_inpainting_denoising.demo_VAE_denoising_inpainting import run_demo
# %matplotlib notebook
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #### Details:
# * <b>model</b>:
#     * 'inpainting': $n_{rem}$ = percentage of the image deleted
#     * 'denoising': $\Delta$ = variance of the additive noise
# * <b>data</b>
#     * 'mnist'
#     * 'fashion_mnist'
# * <b>category</b> $\in [0:9]$
# * <b>max_iter</b>: maximum number of iterations
# * <b>seed</b>: None if $0$
# * <b> plot_prior_sample</b>: shows prior samples
#
#
# * Notations:
#     * $x^\star$: drawn from <b> data </b>
#     * $x_{\rm obs}$: <b>model</b>($x^\star$)
#     * $\hat{x}$: estimator of $x^\star$

# %% [markdown]
# # <center> <em>Inpainting</em> - <font color=#0073d2>MNIST</font> </center>

# %%
run_demo(model='inpainting', data='mnist', category=6, n_rem=20, seed=2, plot_prior_sample=True, plot_evolution=True, max_iter=1000)
# Out:
# mse_ep: 0.001 mse:  0.045
# 1000

# %% [markdown]
# # <center> <em>Denoising</em> - <font color=#0073d2>MNIST</font> </center>

# %%
run_demo(model='denoising', data='mnist', category=6, Delta=2.5, seed=1)
# Out:
# mse_ep: 0.094 mse:  0.044

# %% [markdown]
# # <center> <em>Inpainting</em> - <font color=#a20055>Fashion-MNIST</font> </center>

# %%
run_demo(model='inpainting', data='fashion_mnist', category=4, n_rem=20, seed=1, plot_prior_sample=True)
# Out:
# mse_ep: 0.000 mse:  0.147

# %% [markdown]
# # <center> <em>Denoising</em> - <font color=#a20055>Fashion-MNIST</font> </center>

# %%
run_demo(model='denoising', data='fashion_mnist', category=4, max_iter=1000, Delta=2.5, seed=1)
# Out:
# mse_ep: 0.051 mse:  0.087
